# %%
from langchain_core.documents import Document
from langchain_community.document_loaders import TextLoader

# %%
doc = Document(
    page_content="Hello, world!",
    metadata={"source": "example.txt",
              "pages": [1, 2, 3],
              "author": "ChatGPT",
              "date": "2024-06-15"
              
              } 
     )
print(doc)
# Out:
# page_content='Hello, world!' metadata={'source': 'example.txt', 'pages': [1, 2, 3], 'author': 'ChatGPT', 'date': '2024-06-15'}

# %%
#create a simole txt file 
import os 
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
#textloader
# from langchain.document_loaders import TextLoader
from langchain_community.document_loaders import TextLoader
loader = TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
documents = loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
#Directory Loader
from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={"encoding": "utf-8"},
    show_progress=False
)
document = dir_loader.load()
print(document)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

#Directory Loader
# from langchain_community.document_loaders import DirectoryLoader
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    # loader_kwargs={"encoding": "utf-8"},  
    show_progress=False
)
pdf_document = dir_loader.load()
print(pdf_document)
# Out:
# [Document(metadata={'producer': 'Acrobat Distiller 4.05 for Sparc Solaris', 'creator': 'FrameMaker 5.5 PowerPC: LaserWriter 8 8.7.1', 'creationdate': 'D:20030609082437', 'source': '..\\data\\pdf\\Brown-Giving-PsychSci-2003.pdf', 'file_path': '..\\data\\pdf\\Brown-Giving-PsychSci-2003.pdf', 'total_pages': 8, 'format': 'PDF 1.3', 'title': 'PSCI14461', 'author': 'Comp10', 'subject': '', 'keywords': '', 'moddate': '2003-06-09T15:22:30-04:00', 'trapped': '', 'modDate': "D:20030609152230-04'00'", 'creationDate': 'D:20030609082437', 'page': 0}, page_content='PSYCHOLOGICAL SCIENCE\nResearch Article\n320\nCopyright © 2003 American Psychological Society\nVOL. 14, NO. 4, JULY 2003\nAbstract—This study examines the relative contributions of giving ver-\nsus receiving support to longevity in a sample of older married adults.\nBaseline indicators of giving and receiving support were used to predict\nmortality status over a 5-year period in the Changing Lives of Older\nCouples sample. Results from logistic regression analyses indicated that\nmortality was signiﬁcantly reduced for individuals who reported provid-\ning instrumental support to friends, relatives, and neighbors, and indi-\nviduals who reported providing emotional support to their spouse.\nReceiving support had no effect on mortality once giving support was\ntaken into consideration. This pattern of ﬁndings was obtained after\ncontrolling for demographic, personality, health, mental health, and\nmarital-relationship variables. These results have implications for un-\nderstanding how social contact inﬂuences health and longevity.\nAs demographic shifts have produced a relatively more aged popula-\ntion, factors that inﬂuence longevity have taken on increased promi-\nnence. The documented health beneﬁts of social support may offer a\npromising avenue for reducing mortality among older adults. Indeed,\nthere is a robust association between social contact and health and well-\nbeing (House, Landis, & Umberson, 1988). However, it is not clear that\nreceiving support accounts for these beneﬁts (House et al., 1988). Tests\nof the social-support hypothesis—that receiving support improves\nhealth and well-being—have provided somewhat inconsistent results\n(Kahn, 1994), demonstrating in some instances that receiving support is\nharmful (e.g., S.L. Brown & Vinokur, in press; Hays, Saunders, Flint,\nKaplan, & Blazer, 1997; Seeman, Bruce, & McAvay, 1996). In fact, a\nmeta-analysis of the link between social support and health outcomes\nproduced negligible ﬁndings, leading the study’s authors to conclude\nthat the “small amounts of shared variance [between receiving support\nand health outcomes] may not be considered signiﬁcant nor generaliz-\nable” (Smith, Fernengel, Holcroft, Gerald, & Marien, 1994, p. 352).\nConceptually, it is not clear that receiving social support will always\nbe beneﬁcial. For example, depending on other people for support can\ncause guilt and anxiety (Lu & Argyle, 1992). And feeling like a burden\nto others who presumably provide support is associated with increased\nsuicidal tendencies, even after controlling for depression (R.M. Brown,\nDahlen, Mills, Rick, & Biblarz, 1999; de Catanzaro, 1986). The correla-\ntion of social support with dependence may help to explain why studies\nhave failed to consistently conﬁrm the social-support hypothesis.\nFurthermore, the beneﬁts of social contact may extend beyond re-\nceived support to include other aspects of the interpersonal relation-\nPROVIDING SOCIAL SUPPORT MAY BE MORE BENEFICIAL \nTHAN RECEIVING IT:\nResults From a Prospective Study of Mortality\n \nStephanie L. Brown,1 Randolph M. Nesse,1 Amiram D. Vinokur,1\nand Dylan M. Smith2,3\n1Institute for Social Research, The University of Michigan; 2Department of Internal Medicine, The University of Michigan; and\n3VA Health Services Research & Development Center of Excellence, VA Ann Arbor Healthcare System\nship that may protect health and increase longevity—for example,\ng ...

# %%
type(pdf_document[0])
# Out:
# langchain_core.documents.base.Document
